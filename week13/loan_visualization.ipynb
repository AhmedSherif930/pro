# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
loan=pd.read_csv("loan_data.csv")
loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan[loan['Gender']=="Male"]['LoanAmount'].sum() >loan[loan['Gender']=="Female"]['LoanAmount'].sum()
# Out:
# True

# %%
loan.groupby("Education").sum()["LoanAmount"]
# Out:
# Education
# Graduate        71638.0
# Not Graduate    15038.0
# Name: LoanAmount, dtype: float64

# %%
loan.groupby('Gender')['LoanAmount'].sum()
# Out:
# Gender
# Female    13810.0
# Male      70155.0
# Name: LoanAmount, dtype: float64

# %%
loan.groupby('Married')['LoanAmount'].sum()
# Out:
# Married
# No     26550.0
# Yes    59808.0
# Name: LoanAmount, dtype: float64

# %%
loan.groupby('Self_Employed')['LoanAmount'].sum()
# Out:
# Self_Employed
# No     68323.0
# Yes    13588.0
# Name: LoanAmount, dtype: float64

# %%
sns.pairplot(loan)

# %%
sns.jointplot(loan['ApplicantIncome'],loan['LoanAmount'])
# Out:
# C:\Users\Ahmed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(x='Gender',y='LoanAmount',hue='Married',data=loan)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='LoanAmount'>

# %%
sns.stripplot(x='Gender',y='LoanAmount',hue='Education',data=loan)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='LoanAmount'>

# %%
sns.boxenplot(loan['Self_Employed'],loan['LoanAmount'])
# Out:
# C:\Users\Ahmed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Self_Employed', ylabel='LoanAmount'>

# %%
sns.boxenplot(loan['Education'],loan['LoanAmount'])
# Out:
# C:\Users\Ahmed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Education', ylabel='LoanAmount'>

# %%
sns.jointplot(x='ApplicantIncome',y='LoanAmount',data=loan,hue='Gender')

# %%
sns.jointplot(x='ApplicantIncome',y='LoanAmount',data=loan,hue='Education')

# %%
sns.jointplot(x='ApplicantIncome',y='LoanAmount',data=loan,hue='Credit_History')

# %%
sns.barplot(loan['Dependents'],loan['LoanAmount'])
# Out:
# C:\Users\Ahmed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Dependents', ylabel='LoanAmount'>

# %%
sns.jointplot(x='ApplicantIncome',y='LoanAmount',data=loan,hue='Dependents')

# %%
sns.jointplot(x='CoapplicantIncome',y='LoanAmount',data=loan,hue='Dependents')
